# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Leetcode75/Problem_1071%C2%A0Greatest_Common_Divisor_of_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greatest Common Divisor of Strings - LeetCode

# %% [markdown]
# https://leetcode.com/problems/greatest-common-divisor-of-strings/?envType=study-plan-v2&envId=leetcode-75

# %% [markdown]
# # Предисловие

# %% [markdown]
# Задача: Имея две строки str1 и str2, вернуть наибольшую строку x, такую, что x делит строки str1 и str2.
#
# Для двух строк s и t мы говорим «t делит s» тогда и только тогда, когда s = t + ... + t (т. е. t объединяется сама с собой один или несколько раз)..

# %% [markdown]
# #Решение на бумаге

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Используемые алгоритмы

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# * Сложность алгоритма -

# %% [markdown]
# # Краевые кейсы:

# %% [markdown]
# * Пустой список

# %% [markdown]
# #Код

# %%
var gcdOfStrings = function(str1, str2) {
    if(str1 + str2 != str2 + str1) return '';

    let isValidate = (w,str) =>{
        if(str.length == 0) return true;
        if(!str.startsWith(w)) return false;
        return isValidate(w,str.slice(w.length))
    }

    let res = ''

    for(let i = 1; i<=str1.length; i++){
        let curV = str1.slice(0,i)
        if(isValidate(curV,str2) && isValidate(curV,str1)) res = curV;
    }

    return res;
};

# %% [markdown]
# **Ответ с Leetcode:**

# %% [markdown]
# **Accepted**

# %% [markdown]
# *Надо сделать еще одно условие, чтобы убрать вторую часть*

# %% [markdown]
# #Объяснения от ChatGPT

# %% [markdown]
# The code you provided is an implementation of a function that finds the greatest common divisor (GCD) of two strings. The function is named gcdOfStrings, and it takes two string parameters str1 and str2.
#
# The purpose of the function is to find the longest common divisor of the two strings. The GCD in this context refers to the longest common substring that can be found in both str1 and str2.
#
# Here's how the code works:
#
# 1. Initial Check: The code checks if concatenating str1 and str2 is equal to concatenating str2 and str1. This check ensures that the two strings have the same set of characters. If they don't, it means there is no common divisor, and the function immediately returns an empty string ''.
#
# 2. Validation Function: The code defines an inner function named isValidate that takes two parameters: w (a substring) and str (the remaining string). This function checks if str starts with w and recursively validates the remaining portion of str after removing w. If str becomes empty, it means the entire string has been validated successfully.
#
# 3. Loop and Validation: The code initializes an empty string res to store the result. Then, it loops over the indices of str1 from 1 to its length. At each iteration, it takes a substring curV from str1 starting from index 0 to the current index i. It then uses the isValidate function to check if curV is a valid divisor for both str2 and str1. If it is, the res variable is updated with curV.
#
# 4. Return Result: Finally, the code returns the stored result res, which represents the longest common divisor found in both strings. If no common divisor is found, the result will be an empty string ''.
#
# By executing the gcdOfStrings function with appropriate input strings, you can find the longest common divisor of those strings.
