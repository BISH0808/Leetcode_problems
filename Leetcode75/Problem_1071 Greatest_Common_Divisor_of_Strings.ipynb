# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Leetcode75/Problem_1071%C2%A0Greatest_Common_Divisor_of_Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greatest Common Divisor of Strings - LeetCode

# %% [markdown]
# https://leetcode.com/problems/greatest-common-divisor-of-strings/?envType=study-plan-v2&envId=leetcode-75

# %% [markdown]
# # Предисловие

# %% [markdown]
# Задача: Имея две строки str1 и str2, вернуть наибольшую строку x, такую, что x делит строки str1 и str2.
#
# Для двух строк s и t мы говорим «t делит s» тогда и только тогда, когда s = t + ... + t (т. е. t объединяется сама с собой один или несколько раз)..

# %% [markdown]
# **Что такое Euclidean algorithm?**

# %% [markdown]
# **Объяснения от ChatGPT:**

# %% [markdown]
# The Euclidean algorithm is an efficient method for finding the greatest common divisor (GCD) of two integers. It is named after the ancient Greek mathematician Euclid, who described this algorithm in his work "Elements" around 300 BCE.
#
# The algorithm works by repeatedly dividing the larger number by the smaller number and replacing the larger number with the remainder obtained. This process is repeated until the remainder becomes zero, at which point the last non-zero remainder obtained is the GCD of the original two numbers.
#
# Here's a step-by-step breakdown of the Euclidean algorithm:
#
# 1. Given two positive integers, let's call them a and b, where a is greater than or equal to b.
#
# 2. Divide a by b and obtain the remainder r.
#
# 3. If r is zero, then b is the GCD of a and b, and the algorithm terminates.
#
# 4. If r is not zero, set a to b and b to r (replacing the larger number with the remainder).
#
# 5. Repeat steps 2-4 until the remainder becomes zero.
#
# 6. The last non-zero remainder obtained is the GCD of the original two numbers.
#
# The Euclidean algorithm is widely used for finding the GCD of two numbers due to its simplicity and efficiency. It has applications in various areas of mathematics, computer science, and cryptography. The code you provided earlier utilizes the Euclidean algorithm to calculate the GCD of the lengths of two strings.

# %% [markdown]
# #Решение на бумаге

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Надо добить рисунок*

# %% [markdown]
# #Используемые алгоритмы

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# * Сложность алгоритма -

# %% [markdown]
# # Краевые кейсы:

# %% [markdown]
# * Пустой список

# %% [markdown]
# #Код

# %%
const gcdOfStrings = (str1, str2) => {
  if (str1 + str2 !== str2 + str1) return '';
  const gcd = (a, b) => (0 === b ? a : gcd(b, a % b));
  return str1.substring(0, gcd(str1.length, str2.length));
};

# %% [markdown]
# **Ответ с Leetcode:**

# %% [markdown]
# **Accepted**

# %% [markdown]
# *Надо сделать еще одно условие, чтобы убрать вторую часть*

# %% [markdown]
# #Объяснения от ChatGPT

# %% [markdown]
# The code you provided is an implementation of a function that finds the greatest common divisor (GCD) of two strings. The function is named gcdOfStrings, and it takes two string parameters str1 and str2.
#
# Here's how the code works:
#
# 1. Initial Check: The code checks if concatenating str1 and str2 is equal to concatenating str2 and str1. This check ensures that the two strings have the same set of characters. If they don't, it means there is no common divisor, and the function immediately returns an empty string ''.
#
# 2. GCD Calculation: The code defines an inner function named gcd that calculates the greatest common divisor of two numbers using the Euclidean algorithm. In this case, it calculates the GCD of the lengths of str1 and str2.
#
# 3. GCD Calculation and Return: The code calls the gcd function with the lengths of str1 and str2 as parameters to calculate the GCD. The calculated GCD is used to determine the length of the longest common divisor.
#
# 4. Slicing the Result: Finally, the code uses the substring method on str1 to extract a substring from index 0 to the length of the longest common divisor. This substring represents the longest common divisor found in both strings.
#
# The code returns the extracted substring, which represents the longest common divisor of str1 and str2. If no common divisor is found, or if the initial check fails, the function returns an empty string ''.
#
# By executing the gcdOfStrings function with appropriate input strings, you can find the longest common divisor of those strings.
