# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Leetcode75/Problem_1431_Kids_with_the_Greatest_Number_of_Candies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kids with the Greatest Number of Candies

# %% [markdown]
# https://leetcode.com/problems/kids-with-the-greatest-number-of-candies/?envType=study-plan-v2&envId=leetcode-75

# %% [markdown]
# # Предисловие

# %% [markdown]
# #Решение на бумаге

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Используемые алгоритмы

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# * Сложность алгоритма -

# %% [markdown]
# # Краевые кейсы:

# %% [markdown]
# * Пустой список

# %% [markdown]
# #Код

# %% [markdown]
# **Ответ с Leetcode:**

# %% [markdown]
# #Объяснения от ChatGPT
