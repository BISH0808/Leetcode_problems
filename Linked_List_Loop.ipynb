# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Linked_List_Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **посмотреть потом номер задачи**

# %% [markdown]
# #Linked List Loop (Связный список)

# %% [markdown]
# Суть алгоритма "связный список" рассмотрена в этом [ Notebook](https://colab.research.google.com/drive/1YaDBwFj2kJszdXbgOamamZQLcLNggn7z#scrollTo=ArjAxEfW7bT-)

# %% [markdown]
# Видео, как решает Влад Тен эту задачу можно посмотреть в этом [Video ](https://www.youtube.com/watch?v=b6-_GVGrgzw&list=PLdrkFH5HIVuA8Qx2zReirF-4YTTrMP5KW&index=4&t=442s).

# %% [markdown]
# # Условие задачи

# %% [markdown]
# Дан связный список:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Дано число. Например: 6.

# %% [markdown]
# На выходе нужно вернуть связный список без заданного числа (в данном случае 6).

# %% [markdown]
# # Решение

# %% [markdown]
# 1. Для начала ищем Value, перебирая значения по списку

# %% [markdown]
# 2. Когда находим Value, меняем его со следущим числом местами.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# Сложность алгоритма - O(n)

# %% [markdown]
# # Краевые кейсы:

# %% [markdown]
# * Пустой список
#
# * Все одинаковые значения в списке

# %% [markdown]
# # Код

# %% [markdown]
# **Первое приближение**

# %%
/**
 * Definition for singly-linked list.
 * function ListNode(val, next) {
 *     this.val = (val===undefined ? 0 : val)
 *     this.next = (next===undefined ? null : next)
 * }
 * [0, 1, 2, 3, 4, 5, 6, 8, 6]
 * []
 * [0, 6, 6, 6, 6] =>[]
 */
/**
 * @param {ListNode} head
 * @param {number} val
 * @return {ListNode}
 */
var removeElements = function(head, val) {
 
    let current = head;
   
    if(current === null){
     return head;
    }
    
    while(current.next !== null){
     
   // если нашли элемент
     if(current.next.val === val){
      current.next = current.next.next;
     } else {
      current = curent.next;
     }
    }
    return head;
       
   };
