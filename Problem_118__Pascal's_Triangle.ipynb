# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Problem_118__Pascal's_Triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pascal's Triangle

# %% [markdown]
# https://leetcode.com/problems/pascals-triangle/description/ - на leetcode

# %% [markdown]
# # Условие задачи

# %% [markdown]
# #Используемые алгоритмы

# %% [markdown]
# # Предисловие

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# # Краевые кейсы

# %% [markdown]
# * Пустой список
# * Все одинаковые значения в списке

# %% [markdown]
# # Решение на бумаге

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Код

# %% [markdown]
# Написал код:

# %% [markdown]
# #Ответ с Leetcode:

# %% [markdown]
# *  **Accepted**

# %% [markdown]
# # Решеение с **ChatGPT**

# %% [markdown]
# **На русском**:

# %% [markdown]
# **Начал обсуждать задачу с ChatGPT.**

# %% [markdown]
# Я: хочу решить задачу про Pascal's Triangle
#
# ChatGPT: Отлично! Задача о треугольнике Паскаля — это классическая задача, которая требует генерации треугольника Паскаля до заданного уровня. Какой конкретно вопрос у вас по этой задаче? Можете предоставить условие задачи, и мы начнем обсуждение.

# %% [markdown]
# #Комментарии
