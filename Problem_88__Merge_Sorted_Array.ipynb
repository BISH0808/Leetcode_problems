# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Leetcode_problems/blob/main/Problem_88__Merge_Sorted_Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plus_one

# %% [markdown]
# https://leetcode.com/problems/merge-sorted-array/ - на leetcode

# %% [markdown]
# # Условие задачи

# %% [markdown]
# #Используемые алгоритмы

# %% [markdown]
# # Предисловие

# %% [markdown]
# # Сложность алгоритма

# %% [markdown]
# # Краевые кейсы

# %% [markdown]
# * Пустой список
# * Все одинаковые значения в списке

# %% [markdown]
# # Решение на бумаге

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Код

# %% [markdown]
# Написал код для простого кейса

# %% [markdown]
# #Ответ с Leetcode:

# %% [markdown]
# * не прошел кейс 3

# %% [markdown]
# Надо сделать код с преобразованием массива в число, прибавлением единицы к числу и преобразования числа обратно в массивю.

# %% [markdown]
# Написал код для сложного кейса

# %% [markdown]
# #Ответ с Leetcode:

# %% [markdown]
# * Ошибка вызывалась из-за огрниченного диапазона значений в типе Number. Для этого необходимо использовать тип BigInt.

# %% [markdown]
# **Финальный код**

# %% [markdown]
# #Ответ с Leetcode:

# %% [markdown]
# Accepted

# %% [markdown]
# #Комментарии
